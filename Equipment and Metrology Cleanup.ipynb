# %%
import pandas as pd
import numpy as np
import streamlit as st
import altair as alt
from datetime import datetime as dt

# %%
excel = pd.read_excel('Equipment_and_Metrology_Database.xlsx',index_col='ID #')
temp = pd.DataFrame(excel)
temp.head()
# Out:
#           Location         Type Brand / Component Model #   Serial #  \
# ID #
# 50PROBE01   QC Lab  Thermometer         Traceable     651  210152050
# 50PROBE02   QC Lab  Thermometer         Traceable     651  210151995
# 50PROBE03   QC Lab  Thermometer         Traceable     651  210152045
# 50PROBE04   QC Lab  Thermometer         Traceable     651  210152019
# 50PROBE05   QC Lab  Thermometer         Traceable     651  210152052
#
#                                       Description Specifications  \
# ID #
# 50PROBE01  Ultra-Low Temperature WIFI Data Logger            NaN
# 50PROBE02  Ultra-Low Temperature WIFI Data Logger            NaN
# 50PROBE03  Ultra-Low Temperature WIFI Data Logger            NaN
# 50PROBE04  Ultra-Low Temperature WIFI Data Logger            NaN
# 50PROBE05  Ultra-Low Temperature WIFI Data Logger            NaN
#
#                      Cal. Date        Cal. due Date Qual_Freq OQ/PQ PM SOP  \
# ID #
# 50PROBE01  2023-11-16 00:00:00  2024-11-30 00:00:00    Annual          NaN
# 50PROBE02  2023-11-16 00:00:00  2024-11-30 00:00:00    Annual          NaN
# 50PROBE03  2023-11-16 00:00:00  2024-11-30 00:00:00    Annual          NaN
# 50PROBE04  2023-11-16 00:00:00  2024-11-30 00:00:00    Annual          NaN
# 50PROBE05  2023-11-16 00:00:00  2024-11-30 00:00:00    Annual          NaN
#
#           PM Date  PM Date Next  Comment Owner  Column2
# ID #
# 50PROBE01     NaN           NaN      NaN  Andy      NaN
# 50PROBE02     NaN           NaN      NaN  Andy      NaN
# 50PROBE03     NaN           NaN      NaN  Andy      NaN
# 50PROBE04     NaN           NaN      NaN  Andy      NaN
# 50PROBE05     NaN           NaN      NaN  Andy      NaN

# %%
temp.columns
# Out:
# Index(['Location', 'Type', 'Brand / Component', 'Model #', 'Serial #',
#        'Description', 'Specifications', 'Cal. Date', 'Cal. due Date',
#        'Qual_Freq', 'OQ/PQ PM SOP', 'PM Date', 'PM Date Next', 'Comment',
#        'Owner', 'Column2'],
#       dtype='object')

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 211 entries, 50PROBE01 to nan
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Location           210 non-null    object
#  1   Type               210 non-null    object
#  2   Brand / Component  206 non-null    object
#  3   Model #            200 non-null    object
#  4   Serial #           207 non-null    object
#  5   Description        208 non-null    object
#  6   Specifications     8 non-null      object
#  7   Cal. Date          160 non-null    object
#  8   Cal. due Date      166 non-null    object
#  9   Qual_Freq          175 non-null    object
#  10  OQ/PQ PM SOP       130 non-null    object
#  11  PM Date            1 non-null      object
#  12  PM Date Next       0 non-null      float64
#  13  Comment            0 non-null      float64
#  14  Owner              118 non-null    object
#  15  Column2            0 non-null      float64
# dtypes: float64(3), object(13)
# memory usage: 28.0+ KB

# %%
tests = temp['Cal. Date'].astype(str)
dates = []
for test in tests:
    dates.append(test[:-9])
temp['Cal. Date']=dates
temp.head()
# Out:
#           Location         Type Brand / Component Model #   Serial #  \
# ID #
# 50PROBE01   QC Lab  Thermometer         Traceable     651  210152050
# 50PROBE02   QC Lab  Thermometer         Traceable     651  210151995
# 50PROBE03   QC Lab  Thermometer         Traceable     651  210152045
# 50PROBE04   QC Lab  Thermometer         Traceable     651  210152019
# 50PROBE05   QC Lab  Thermometer         Traceable     651  210152052
#
#                                       Description Specifications   Cal. Date  \
# ID #
# 50PROBE01  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 50PROBE02  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 50PROBE03  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 50PROBE04  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 50PROBE05  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
#
#                  Cal. due Date Qual_Freq OQ/PQ PM SOP PM Date  PM Date Next  \
# ID #
# 50PROBE01  2024-11-30 00:00:00    Annual          NaN     NaN           NaN
# 50PROBE02  2024-11-30 00:00:00    Annual          NaN     NaN           NaN
# 50PROBE03  2024-11-30 00:00:00    Annual          NaN     NaN           NaN
# 50PROBE04  2024-11-30 00:00:00    Annual          NaN     NaN           NaN
# 50PROBE05  2024-11-30 00:00:00    Annual          NaN     NaN           NaN
#
#            Comment Owner  Column2
# ID #
# 50PROBE01      NaN  Andy      NaN
# 50PROBE02      NaN  Andy      NaN
# 50PROBE03      NaN  Andy      NaN
# 50PROBE04      NaN  Andy      NaN
# 50PROBE05      NaN  Andy      NaN

# %%
date = temp['Cal. due Date'].astype(str)
why = []
for date in date:
    why.append(date[:-9])
temp['Cal. due Date'] = why
temp.head()
# Out:
#           Location         Type Brand / Component Model #   Serial #  \
# ID #
# 50PROBE01   QC Lab  Thermometer         Traceable     651  210152050
# 50PROBE02   QC Lab  Thermometer         Traceable     651  210151995
# 50PROBE03   QC Lab  Thermometer         Traceable     651  210152045
# 50PROBE04   QC Lab  Thermometer         Traceable     651  210152019
# 50PROBE05   QC Lab  Thermometer         Traceable     651  210152052
#
#                                       Description Specifications   Cal. Date  \
# ID #
# 50PROBE01  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 50PROBE02  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 50PROBE03  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 50PROBE04  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 50PROBE05  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
#
#           Cal. due Date Qual_Freq OQ/PQ PM SOP PM Date  PM Date Next  Comment  \
# ID #
# 50PROBE01    2024-11-30    Annual          NaN     NaN           NaN      NaN
# 50PROBE02    2024-11-30    Annual          NaN     NaN           NaN      NaN
# 50PROBE03    2024-11-30    Annual          NaN     NaN           NaN      NaN
# 50PROBE04    2024-11-30    Annual          NaN     NaN           NaN      NaN
# 50PROBE05    2024-11-30    Annual          NaN     NaN           NaN      NaN
#
#           Owner  Column2
# ID #
# 50PROBE01  Andy      NaN
# 50PROBE02  Andy      NaN
# 50PROBE03  Andy      NaN
# 50PROBE04  Andy      NaN
# 50PROBE05  Andy      NaN

# %%
temp.columns
# Out:
# Index(['Location', 'Type', 'Brand / Component', 'Model #', 'Serial #',
#        'Description', 'Specifications', 'Cal. Date', 'Cal. due Date',
#        'Qual_Freq', 'OQ/PQ PM SOP', 'PM Date', 'PM Date Next', 'Comment',
#        'Owner', 'Column2'],
#       dtype='object')

# %%
temp = temp.loc[:,['Location', 'Type', 'Serial #', 'Description', 'Cal. Date', 'Cal. due Date',
                   'Comment', 'Owner']]
temp.head()
# Out:
#           Location         Type   Serial #  \
# ID #
# 50PROBE01   QC Lab  Thermometer  210152050
# 50PROBE02   QC Lab  Thermometer  210151995
# 50PROBE03   QC Lab  Thermometer  210152045
# 50PROBE04   QC Lab  Thermometer  210152019
# 50PROBE05   QC Lab  Thermometer  210152052
#
#                                       Description   Cal. Date Cal. due Date  \
# ID #
# 50PROBE01  Ultra-Low Temperature WIFI Data Logger  2023-11-16    2024-11-30
# 50PROBE02  Ultra-Low Temperature WIFI Data Logger  2023-11-16    2024-11-30
# 50PROBE03  Ultra-Low Temperature WIFI Data Logger  2023-11-16    2024-11-30
# 50PROBE04  Ultra-Low Temperature WIFI Data Logger  2023-11-16    2024-11-30
# 50PROBE05  Ultra-Low Temperature WIFI Data Logger  2023-11-16    2024-11-30
#
#            Comment Owner
# ID #
# 50PROBE01      NaN  Andy
# 50PROBE02      NaN  Andy
# 50PROBE03      NaN  Andy
# 50PROBE04      NaN  Andy
# 50PROBE05      NaN  Andy

# %%
temp.dropna()
# Out:
# Empty DataFrame
# Columns: [Location, Type, Serial #, Description, Cal. Date, Cal. due Date, Comment, Owner]
# Index: []

# %%
temp.head()
# Out:
#           Location         Type   Serial #  \
# ID #
# 50PROBE01   QC Lab  Thermometer  210152050
# 50PROBE02   QC Lab  Thermometer  210151995
# 50PROBE03   QC Lab  Thermometer  210152045
# 50PROBE04   QC Lab  Thermometer  210152019
# 50PROBE05   QC Lab  Thermometer  210152052
#
#                                       Description   Cal. Date Cal. due Date  \
# ID #
# 50PROBE01  Ultra-Low Temperature WIFI Data Logger  2023-11-16    2024-11-30
# 50PROBE02  Ultra-Low Temperature WIFI Data Logger  2023-11-16    2024-11-30
# 50PROBE03  Ultra-Low Temperature WIFI Data Logger  2023-11-16    2024-11-30
# 50PROBE04  Ultra-Low Temperature WIFI Data Logger  2023-11-16    2024-11-30
# 50PROBE05  Ultra-Low Temperature WIFI Data Logger  2023-11-16    2024-11-30
#
#            Comment Owner
# ID #
# 50PROBE01      NaN  Andy
# 50PROBE02      NaN  Andy
# 50PROBE03      NaN  Andy
# 50PROBE04      NaN  Andy
# 50PROBE05      NaN  Andy

# %%
temp.to_csv('Equipment and Metrology.csv', index=True)

# %% [markdown]
# ### Create Streamlit Page

# %%
file = 'Equipment and Metrology.csv'
st.set_page_config(layout='wide')
st.title('Equipment and Metrology')
# Out:
# 2024-02-29 15:29:05.663
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\carlp\miniconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()

# %%
@st.cache
def load_data():
    df = pd.read_csv(file, index_col=False)
    return df

df = load_data

# %%
def search(data, column, search_term):
    if column == 'Location':
        search_term = (search_term)

    indexes = df.loc[df[column].isin([search_term])].index
    if indexes.size > 0:
        return df.iloc[indexes]
    else:
        return []

# %%
with st.sidebar("inputs"):
    key = st.selectbox("Key", ['ID Number', 'Location', 'Serial Number', 'Description', 'Cal. Date', 'Cal. due Date', 'Owner'])
    search_term = st.text_input("Search")
    if key != '' and search_term != '':
        df = search(df, key, search_term)
    if not df.empty:
        st.dataframe(df)
    else:
        st.write('Did not find any matching criteria')
