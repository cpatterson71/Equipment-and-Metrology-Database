# %%
import pandas as pd
import numpy as np
import streamlit as st
import altair as alt
from datetime import datetime as dt

# %%
file = 'Equipment_and_Metrology_Database.xlsx'
excel = pd.read_excel(file,index_col=False)
temp = pd.DataFrame(excel)
temp.head()
# Out:
#         ID # Location         Type Brand / Component Model #   Serial #  \
# 0  50PROBE01   QC Lab  Thermometer         Traceable     651  210152050
# 1  50PROBE02   QC Lab  Thermometer         Traceable     651  210151995
# 2  50PROBE03   QC Lab  Thermometer         Traceable     651  210152045
# 3  50PROBE04   QC Lab  Thermometer         Traceable     651  210152019
# 4  50PROBE05   QC Lab  Thermometer         Traceable     651  210152052
#
#                               Description Specifications             Cal_Date  \
# 0  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16 00:00:00
# 1  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16 00:00:00
# 2  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16 00:00:00
# 3  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16 00:00:00
# 4  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16 00:00:00
#
# ...

# %%
temp.columns
# Out:
# Index(['ID #', 'Location', 'Type', 'Brand / Component', 'Model #', 'Serial #',
#        'Description', 'Specifications', 'Cal_Date', 'Cal_Due_Date',
#        'Qualification\n Frequency', 'OQ/PQ PM SOP', 'PM Date', 'PM Date Next',
#        'Comment', 'Owner', 'Column2'],
#       dtype='object')

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID #                      206 non-null    object
#  1   Location                  215 non-null    object
#  2   Type                      215 non-null    object
#  3   Brand / Component         211 non-null    object
#  4   Model #                   205 non-null    object
#  5   Serial #                  212 non-null    object
#  6   Description               213 non-null    object
#  7   Specifications            13 non-null     object
#  8   Cal_Date                  162 non-null    object
#  9   Cal_Due_Date              168 non-null    object
#  10  Qualification
#  Frequency  175 non-null    object
#  11  OQ/PQ PM SOP              130 non-null    object
#  12  PM Date                   1 non-null      object
# ...

# %%
tests = temp['Cal_Date'].astype(str)
dates = []
for test in tests:
    dates.append(test[:-9])
temp['Cal_Date']=dates
temp.head()
# Out:
#         ID # Location         Type Brand / Component Model #   Serial #  \
# 0  50PROBE01   QC Lab  Thermometer         Traceable     651  210152050
# 1  50PROBE02   QC Lab  Thermometer         Traceable     651  210151995
# 2  50PROBE03   QC Lab  Thermometer         Traceable     651  210152045
# 3  50PROBE04   QC Lab  Thermometer         Traceable     651  210152019
# 4  50PROBE05   QC Lab  Thermometer         Traceable     651  210152052
#
#                               Description Specifications    Cal_Date  \
# 0  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 1  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 2  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 3  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 4  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
#
#           Cal_Due_Date Qualification\n Frequency OQ/PQ PM SOP PM Date  \
# ...

# %%
date = temp['Cal_Due_Date'].astype(str)
why = []
for date in date:
    why.append(date[:-9])
temp['Cal_Due_Date'] = why
temp.head()
# Out:
#         ID # Location         Type Brand / Component Model #   Serial #  \
# 0  50PROBE01   QC Lab  Thermometer         Traceable     651  210152050
# 1  50PROBE02   QC Lab  Thermometer         Traceable     651  210151995
# 2  50PROBE03   QC Lab  Thermometer         Traceable     651  210152045
# 3  50PROBE04   QC Lab  Thermometer         Traceable     651  210152019
# 4  50PROBE05   QC Lab  Thermometer         Traceable     651  210152052
#
#                               Description Specifications    Cal_Date  \
# 0  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 1  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 2  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 3  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
# 4  Ultra-Low Temperature WIFI Data Logger            NaN  2023-11-16
#
#   Cal_Due_Date Qualification\n Frequency OQ/PQ PM SOP PM Date  PM Date Next  \
# ...

# %%
temp.columns

# %%
temp = temp.loc[:,['ID #','Location', 'Type', 'Serial #', 'Description', 'Cal_Date', 'Cal_Due_Date',
                   'Owner', 'Comment']]
temp.head()
# Out:
#         ID # Location         Type   Serial #  \
# 0  50PROBE01   QC Lab  Thermometer  210152050
# 1  50PROBE02   QC Lab  Thermometer  210151995
# 2  50PROBE03   QC Lab  Thermometer  210152045
# 3  50PROBE04   QC Lab  Thermometer  210152019
# 4  50PROBE05   QC Lab  Thermometer  210152052
#
#                               Description    Cal_Date Cal_Due_Date Owner  \
# 0  Ultra-Low Temperature WIFI Data Logger  2023-11-16   2024-11-30  Andy
# 1  Ultra-Low Temperature WIFI Data Logger  2023-11-16   2024-11-30  Andy
# 2  Ultra-Low Temperature WIFI Data Logger  2023-11-16   2024-11-30  Andy
# 3  Ultra-Low Temperature WIFI Data Logger  2023-11-16   2024-11-30  Andy
# 4  Ultra-Low Temperature WIFI Data Logger  2023-11-16   2024-11-30  Andy
#
#    Comment
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID #          206 non-null    object
#  1   Location      215 non-null    object
#  2   Type          215 non-null    object
#  3   Serial #      212 non-null    object
#  4   Description   213 non-null    object
#  5   Cal_Date      216 non-null    object
#  6   Cal_Due_Date  216 non-null    object
#  7   Owner         118 non-null    object
#  8   Comment       0 non-null      float64
# dtypes: float64(1), object(8)
# memory usage: 15.3+ KB

# %%
temp['Cal_Date'] = pd.to_datetime(temp['Cal_Date'], format='%Y-%m-%d')
temp['Cal_Due_Date'] = pd.to_datetime(temp['Cal_Due_Date'], format='%Y-%m-%d')
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID #          206 non-null    object
#  1   Location      215 non-null    object
#  2   Type          215 non-null    object
#  3   Serial #      212 non-null    object
#  4   Description   213 non-null    object
#  5   Cal_Date      159 non-null    datetime64[ns]
#  6   Cal_Due_Date  166 non-null    datetime64[ns]
#  7   Owner         118 non-null    object
#  8   Comment       0 non-null      float64
# dtypes: datetime64[ns](2), float64(1), object(6)
# memory usage: 15.3+ KB

# %%
temp.head()
# Out:
#         ID # Location         Type   Serial #  \
# 0  50PROBE01   QC Lab  Thermometer  210152050
# 1  50PROBE02   QC Lab  Thermometer  210151995
# 2  50PROBE03   QC Lab  Thermometer  210152045
# 3  50PROBE04   QC Lab  Thermometer  210152019
# 4  50PROBE05   QC Lab  Thermometer  210152052
#
#                               Description   Cal_Date Cal_Due_Date Owner  \
# 0  Ultra-Low Temperature WIFI Data Logger 2023-11-16   2024-11-30  Andy
# 1  Ultra-Low Temperature WIFI Data Logger 2023-11-16   2024-11-30  Andy
# 2  Ultra-Low Temperature WIFI Data Logger 2023-11-16   2024-11-30  Andy
# 3  Ultra-Low Temperature WIFI Data Logger 2023-11-16   2024-11-30  Andy
# 4  Ultra-Low Temperature WIFI Data Logger 2023-11-16   2024-11-30  Andy
#
#    Comment
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
temp.to_csv('Equipment_Metrology_Database.csv', index=False)

# %%
beg_date = input('Beggining Date (YYYY-MM-DD): ')

# %%
end_date = input('Ending Date (YYYY-MM-DD): ')

# %%
filtered_dates = temp.loc[(temp['Cal_Due_Date'] > beg_date) & (temp['Cal_Due_Date'] <= end_date)]
filtered_dates

# %%
filtered_dates.to_excel('Equipment_Due_List '+ beg_date +'_'+ end_date +'.xlsx', index=False)
